# %% [markdown]
# @author: Octavio Gutiérrez de Código Máquina
#
# URL del canal: https://www.youtube.com/CodigoMaquina
#
# URL del video: https://youtu.be/yOCJQLf_YFI
#
#
# <img src="imagenes/bosquesaleatorios.png" width="680" align="left">
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>

# %% [markdown]
# <h1 style="color:darkred;"> Bosques Aleatorios: ¿Ingreso Alto o Bajo? </h1>
# <h2> Horas trabajadas, Años de Estudio, Edad, Tipo trabajo, ...</h2>

# %% [markdown]
# <h1 style="color:darkorange;"> Árbol 1 </h1>
# <img src="imagenes/arbol1.png" width="300" align="left">
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>
# <h1 style="color:darkorange;"> Árbol 2 </h1>
# <img src="imagenes/arbol2.png" width="625" align="left">
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>
# <h1 style="color:darkorange;"> Árbol 3 </h1>
# <img src="imagenes/arbol3.png" width="400" align="left">
#
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>
# <h1 style="color:darkorange;"> Bosque Aleatorio </h1>
# <img src="imagenes/bosque.png" width="725" align="left">

# %% [markdown]
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>

# %% [markdown]
# <h1 style="color:darkred;"> Aleatoriedad: </h1>
# <h1 style="color:darkred;"> Muestreo con reemplazo </h1>
# <h2 style="color:darkblue;"> >>>>> max_samples <<<<< </h2>

# %%
import pandas as pd 

personas = pd.read_csv("datos/ingresos.csv")

print(personas.sample(frac=2/3, replace=True))
print(personas.sample(frac=2/3, replace=True))
print(personas.sample(frac=2/3, replace=True))
print(personas.sample(frac=2/3, replace=True))
print(personas.sample(frac=2/3, replace=True))
# Out:
#     edad  estudio  genero  tipo_trabajo  horas  ingreso
# 64    56        9       1             1     50        0
# 88    24        3       1             0     60        0
# 38    47        9       1             0     40        0
# 57    62       13       1             0      1        1
# 11    31       10       1             0     40        0
# ..   ...      ...     ...           ...    ...      ...
# 86    21        9       0             0     44        0
# 33    30        6       1             0     55        0
# 26    28        9       1             0     45        1
# 82    49        9       1             0     40        0
# 75    50        9       1             1     40        0
#
# [67 rows x 6 columns]
#     edad  estudio  genero  tipo_trabajo  horas  ingreso
# 17    67       16       1             0     60        1
# 87    32       13       1             0     45        0
# 70    21       10       1             0     50        0
# 99    47        9       1             0     12        0
# 16    80        9       1             1     30        0
# ..   ...      ...     ...           ...    ...      ...
# 89    53        9       1             1     40        1
# 64    56        9       1             1     50        0
# 44    36       14       1             0     60        1
# 80    38       10       0             1     50        0
# 64    56        9       1             1     50        0
#
# [67 rows x 6 columns]
#     edad  estudio  genero  tipo_trabajo  horas  ingreso
# 31    45        4       1             0     10        0
# 10    49        3       0             0     20        0
# 43    49       10       1             0     44        1
# 68    58       13       1             0     40        0
# 77    19        5       1             0     40        0
# ..   ...      ...     ...           ...    ...      ...
# 90    59        9       0             0     35        0
# 72    63       14       1             1     40        1
# 10    49        3       0             0     20        0
# 83    36       10       1             0     55        1
# 8     68        9       1             1     25        0
#
# [67 rows x 6 columns]
#     edad  estudio  genero  tipo_trabajo  horas  ingreso
# 17    67       16       1             0     60        1
# 61    43       10       0             0     35        0
# 58    21       10       0             1     40        0
# 40    59       13       1             0     40        1
# 45    54       13       1             1     40        1
# ..   ...      ...     ...           ...    ...      ...
# 30    20        9       1             0     40        0
# 96    20       10       0             0     25        0
# 89    53        9       1             1     40        1
# 57    62       13       1             0      1        1
# 83    36       10       1             0     55        1
#
# [67 rows x 6 columns]
#     edad  estudio  genero  tipo_trabajo  horas  ingreso
# 18    17        8       1             0     15        0
# 8     68        9       1             1     25        0
# 53    64        5       1             1     40        0
# 78    52       16       1             1     70        1
# 17    67       16       1             0     60        1
# ..   ...      ...     ...           ...    ...      ...
# 48    19        9       0             1     35        0
# 91    20        9       1             1     40        0
# 52    35        9       1             1     60        0
# 12    66       11       0             0     30        0
# 22    59        9       1             1     40        0
#
# [67 rows x 6 columns]

# %% [markdown]
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>

# %% [markdown]
# <h1 style="color:darkred;"> Aleatoriedad: </h1>
# <h1 style="color:darkred;"> Selección de las Características para Divisiones </h1>
# <h2 style="color:darkblue;"> >>>>> max_features = √num_características <<<<< </h2>

# %%
from random import sample

print(personas.columns[:-1], "\n")
print(sample(set(personas.columns[:-1]), 3))
# Out:
# Index(['edad', 'estudio', 'genero', 'tipo_trabajo', 'horas'], dtype='object')
#
# ['edad', 'estudio', 'horas']

# %% [markdown]
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>

# %% [markdown]
# <h1 style="color:darkred;"> Creación de Bosque Aleatorio (Random Forest) </h1>

# %%
from sklearn.ensemble import RandomForestClassifier

bosque = RandomForestClassifier(n_estimators=100,
                               criterion="gini",
                               max_features="sqrt",
                               bootstrap=True,
                               max_samples=2/3,
                               oob_score=True)

bosque.fit(personas[personas.columns[:-1]].values, personas["ingreso"].values)

print(bosque.predict([[50, 16, 1, 1, 40]]))
print(bosque.score(personas[personas.columns[:-1]].values, personas["ingreso"].values))
print(bosque.oob_score_)
# Out:
# [1]
# 0.98
# 0.76

# %% [markdown]
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>

# %% [markdown]
# <h1 style="color:darkred;"> Visualización del Bosque Aleatorio</h1>

# %%
import matplotlib.pyplot as plt
from sklearn import tree

for arbol in bosque.estimators_:
    tree.plot_tree(arbol, feature_names=personas.columns[:-1])
    plt.show()

# %% [markdown]
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>

# %% [markdown]
# # Referencia

# %% [markdown]
# ## Breiman, "Random Forests", Machine Learning, 45(1), 5-32, 2001.

# %% [markdown]
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>
