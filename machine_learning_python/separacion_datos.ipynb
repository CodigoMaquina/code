# %% [markdown]
# @author: Octavio Gutiérrez de Código Máquina
#
# URL del canal: https://www.youtube.com/CodigoMaquina
#
# URL del video: https://youtu.be/vdYzm4xC7mc
#
#
# # Machine Learning
# ## Datos para Entrenamiento, Validación y Prueba
# <BR>

# %% [markdown]
# <img src="imagenes/uno.jpg"  width="800"><BR><BR><BR><BR><BR><BR><BR>
# <img src="imagenes/dos.jpg"  width="800"><BR><BR><BR><BR><BR><BR><BR>
# <img src="imagenes/tres.jpg"  width="800"><BR><BR><BR><BR><BR><BR><BR>
# <img src="imagenes/separacion_datos.jpg"  width="800">

# %% [markdown]
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>

# %% [markdown]
# # Separación de Datos:
# ### 60% Entrenamiento, 20% Validación, 20% Prueba

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

pacientes = pd.read_csv("problemas_del_corazon.csv")
pacientes

resto, prueba, resto_clase, prueba_clase = train_test_split(
    pacientes[["edad", "genero", "presion", "colesterol", "diabetico"]],
    pacientes["cardiaco"], 
    test_size=0.20)

entrena, valida, entrena_clase, valida_clase = train_test_split(
    resto[["edad", "genero", "presion", "colesterol", "diabetico"]],
    resto_clase, 
    test_size=0.25)

pacientes[pacientes["cardiaco"]==1]
# Out:
#     edad  genero  presion  colesterol  diabetico  cardiaco
# 0     53       0      128         216          0         1
# 1     53       0      138         234          0         1
# 2     51       0      130         256          0         1
# 3     66       1      120         302          0         1
# 4     62       1      130         231          0         1
# 5     44       0      108         141          0         1
# 6     63       0      135         252          0         1
# 7     52       1      134         201          0         1
# 8     48       1      122         222          0         1
# 9     45       1      115         260          0         1
# 10    34       1      118         182          0         1
# 11    57       0      128         303          0         1
# 12    71       0      110         265          1         1
# 13    54       1      108         309          0         1
# 14    52       1      118         186          0         1
# 15    41       1      135         203          0         1
# 16    58       1      140         211          1         1
# 17    35       0      138         183          0         1
# 18    51       1      100         222          0         1
# 19    45       0      130         234          0         1
# 20    44       1      120         220          0         1
# 21    62       0      124         209          0         1
# 22    54       1      120         258          0         1
# 23    51       1       94         227          0         1
# 24    29       1      130         204          0         1
# 25    51       1      140         261          0         1
# 26    43       0      122         213          0         1
# 27    55       0      135         250          0         1
# 28    51       1      125         245          1         1
# 29    59       1      140         221          0         1
# 30    52       1      128         205          1         1
# 31    58       1      105         240          0         1
# 32    41       1      112         250          0         1
# 33    45       1      128         308          0         1
# 34    60       0      102         318          0         1
# 35    52       1      152         298          1         1
# 36    42       0      102         265          0         1
# 37    67       0      115         564          0         1
# 38    68       1      118         277          0         1
# 39    46       1      101         197          1         1
# 40    54       0      110         214          0         1
# 41    58       0      100         248          0         1
# 42    48       1      124         255          1         1
# 43    57       1      132         207          0         1
# 44    52       1      138         223          0         1
# 45    54       0      132         288          1         1
# 46    45       0      112         160          0         1
# 47    53       1      142         226          0         1
# 48    62       0      140         394          0         1
# 49    52       1      108         233          1         1

# %% [markdown]
# <BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR><BR>
