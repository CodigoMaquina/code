# %% [markdown]
# <!--
# @author: Octavio Gutiérrez de Código Máquina
#
# URL del canal: https://www.youtube.com/CodigoMaquina
#
# URL del video: https://youtu.be/x-7BHjMA15M
#
# -->

# %% [markdown]
# @author: Octavio Gutiérrez de Código Máquina
#
# URL del canal: https://www.youtube.com/CodigoMaquina
#
# URL del video: https://youtu.be/Mq4lF0eEw8s
#
# <h1 style="color:purple;">Datos a Visualizar con Seaborn</h1>

# %%
# ["especie", "isla", "longitud_pico", "profundidad_pico", "longitud_aleta", "masa", "sexo"]
import matplotlib.pyplot as plt
import seaborn as sns

pinguinos = sns.load_dataset("penguins")
pinguinos.columns = ["especie", "isla", "longitud_pico", "profundidad_pico",
                     "longitud_aleta", "masa", "sexo"]
pinguinos
# Out:
#     especie       isla  longitud_pico  profundidad_pico  longitud_aleta  \
# 0    Adelie  Torgersen           39.1              18.7           181.0
# 1    Adelie  Torgersen           39.5              17.4           186.0
# 2    Adelie  Torgersen           40.3              18.0           195.0
# 3    Adelie  Torgersen            NaN               NaN             NaN
# 4    Adelie  Torgersen           36.7              19.3           193.0
# ..      ...        ...            ...               ...             ...
# 339  Gentoo     Biscoe            NaN               NaN             NaN
# 340  Gentoo     Biscoe           46.8              14.3           215.0
# 341  Gentoo     Biscoe           50.4              15.7           222.0
# 342  Gentoo     Biscoe           45.2              14.8           212.0
# 343  Gentoo     Biscoe           49.9              16.1           213.0
#
#        masa    sexo
# 0    3750.0    Male
# 1    3800.0  Female
# 2    3250.0  Female
# ...

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
# <h1 style="color:darkblue;"> Primera gráfica de Seaborn</h1>
# <h2 style="color:indianred;"> <span style="color:purple;">Estilos:</span> white, dark, whitegrid, darkgrid, ticks</h2>
# <h2 style="color:indianred;"> <span style="color:purple;">Contextos:</span> paper, notebook, talk, poster</h2>

# %%
sns.set_theme(style="ticks", context="talk")
relacional = sns.relplot(data=pinguinos,
                        height=7,
                        aspect=1.2,
                        markers=["s", ".", "P", "d"])
relacional.set(title="Análisis de Pingüinos")
relacional.set_ylabels("Variables")
relacional.set_xlabels("Número de Pingüino")
plt.show()

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
# <h1 style="color:purple;">Diagramas de Dispersión</h1>

# %%
print(">>>>>>>>>>>>>>>>>>>> SIMPLE")

sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta")

print(">>>>>>>>>>>>>>>>>>>> MATIZ Y TAMAÑO FIJO")

fig = sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta",
           hue="masa",
           size="masa",
           sizes=(100, 500))

fig.savefig("out.png", transparent=True) 


sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta",
           hue="especie",
           s=300)

print(">>>>>>>>>>>>>>>>>>>> REJILLA, TAMAÑO PERSONALIZADO Y ESTILO")

sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta",
           hue="especie",
           row="sexo",
           size="masa",
           sizes=(100, 500),
           style="sexo")

sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta",
           hue="especie",
           col="isla",
           row="sexo",            
           size="masa",
           sizes=(100, 500),
           style="sexo")
# Out:
# >>>>>>>>>>>>>>>>>>>> SIMPLE
# >>>>>>>>>>>>>>>>>>>> MATIZ Y TAMAÑO FIJO
# >>>>>>>>>>>>>>>>>>>> REJILLA, TAMAÑO PERSONALIZADO Y ESTILO

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
# <h1 style="color:purple;">Gráficos de Líneas</h1>

# %%
sns.relplot(data=pinguinos,
           x="especie",
           y="masa",
           kind="line",
           hue="sexo",
           style="sexo",
           ci="sd")
plt.show()

fig = sns.relplot(data=pinguinos,
           x="profundidad_pico",
           y="longitud_pico",
           kind="line",
           hue="especie",
           style="especie",
           row="especie",
           color="cyan",
           ci="sd")

fig.savefig("out3.png", transparent=True) 

plt.show()

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
# <h1 style="color:purple;">Combinando Gráficos</h1>
# <h2 style="color:darkblue;">Líneas y Dispersión</h2>

# %%
figura, ejes = plt.subplots(1, 2, figsize=(15, 5))

sns.lineplot(data=pinguinos,
           x="especie",
           y="masa",
           hue="sexo",
           style="sexo",
           ax=ejes[0])

    
sns.scatterplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta",
           hue="especie",
           s=300,
           ax=ejes[1])

figura.savefig("out2.png", transparent=True) 

plt.show()

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
